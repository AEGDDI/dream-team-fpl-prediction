# %%
import os
import pandas as pd
from unidecode import unidecode
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# Load the players_agg.xlsx file
players_agg_path = r'C:\Users\aldi\Documents\GitHub\dream-team-fpl-prediction\data\players_agg.xlsx'
#players_agg_path = r'C:\Users\ALESSANDRO\Documents\GitHub\dream-team-fpl-prediction\data\players_agg.xlsx'
players_agg_df = pd.read_excel(players_agg_path)

# Load the fpl_data.csv file
fpl_data_path = r'C:\Users\aldi\Documents\GitHub\dream-team-fpl-prediction\data\fpl_data.xlsx'
#fpl_data_path = r'C:\Users\ALESSANDRO\Documents\GitHub\dream-team-fpl-prediction\data\fpl_data.csv'
fpl_data_df = pd.read_excel(fpl_data_path)

# Clean the 'Player' column in players_agg_df
players_agg_df['Player'] = players_agg_df['Player'].apply(unidecode)

# Clean the 'Player' column in fpl_data_df
fpl_data_df['Player'] = fpl_data_df['Player'].apply(unidecode)

# Filter the players_agg_df for season 2016-2017 onwards
players_agg_df = players_agg_df[players_agg_df['Season'] >= '2016-2017']

# Extract surname and first_name from 'Player' column in both datasets
players_agg_df['surname'] = players_agg_df['Player'].apply(lambda name: name.split()[-1])
players_agg_df['first_name'] = players_agg_df['Player'].apply(lambda name: ' '.join(name.split()[:-1]))
fpl_data_df['surname'] = fpl_data_df['Player'].apply(lambda name: name.split()[-1])
fpl_data_df['first_name'] = fpl_data_df['Player'].apply(lambda name: ' '.join(name.split()[:-1]))

# Perform an outer join on 'Player' and 'Season' variables
merged_df = pd.merge(players_agg_df, fpl_data_df, on=['Player', 'Season'], how='outer')

# %%
# Filter the merged_df for the season 2016-2017
filtered_df = merged_df[merged_df['Season'] >= '2016-2017'].copy()

# %%
# Clean some dirty characters
filtered_df['Player'] = filtered_df['Player'].str.replace('A\(c\)','e')
filtered_df['Player'] = filtered_df['Player'].str.replace('A\(r\)','i')
filtered_df['Player'] = filtered_df['Player'].str.replace('A 1/4 ','u')
filtered_df['Player'] = filtered_df['Player'].str.replace('A-','i')
filtered_df['Player'] = filtered_df['Player'].str.replace('A\+-','n')
filtered_df['Player'] = filtered_df['Player'].str.replace('A,','o')
filtered_df['Player'] = filtered_df['Player'].str.replace('A!','a')

# %%
# All unique player names
names = list(filtered_df['Player'].unique())

# %%
# Build a dictionary with all names matched by the algorithm for each name in the list
THRESHOLD = 0.7
matches = dict()
for name in names:
    results = process.extractBests(name, names, scorer=fuzz.token_set_ratio,
                                   score_cutoff=THRESHOLD)
    matches[name] = []
    for result in results:
        if result[0] == name:
            continue
        if result[1] > 80:
            matches[name].append(result)

# %%
# Empty dict that will store for each name:
# - The name to which it maps to (e.g. 'Aleix Garcia Serrano' maps to 'Aleix Garcia')
# - The name(s) that maps to it (e.g. 'Aleix Garcia' is mapped by 'Aleix Garcia')
# - The name(s) that are a false match (e.g. 'Alexis Sanchez' is ignored by 'Aleix Garcia')
matches_final = dict()

# %%
# For every unique name build an empty dict that will store the data
for name in matches.keys():
    
    # If the algorithm didn't find any possible match is skipped
    if len(matches[name]) == 0:
        continue
    
    # Empty dict for the name
    matches_final[name] = {
        'Mapped_by': set(),  # If exists, a set of name(s) that refer to this name
        'Maps_to': '',       # If exists, a name to which this one should refer to
        'Ignores': set()     # If exists, a set of bad matches that should be ignored
        }

# %%
### For every name that had at least a match by the algorithm...
for name in matches_final.keys(): 
    
    # -------------------- MULTI-NAME CHECK SECTION --------------------
    # This part of the code checks wheter all the names that have a possible relationship refer
    # to the same player or not
    
    # Starting from a name (name) gathers all the name that could be related and stores them in the
    # names_checked list
    names_to_check = [name]
    names_checked = []
    while len(names_to_check) > 0:
        for el in matches[names_to_check[0]]:
            if el[0] not in names_checked:
                if el[0] not in names_to_check:
                    names_to_check.append(el[0])
        names_checked.append(names_to_check[0])
        names_to_check.pop(0)
    
    # Asks wheter all those names refer to the same player; if so, it asks to point which name is
    # the correct one and the data will be updated accordingly
    print('\nDo the following names all refer to the same player?')
    for el in names_checked:
        print(f' {names_checked.index(el)+1}. {el}')
    idx = input('If so, enter the number of the proper name, otherwise enter nothing: ')
    
    if idx.isdigit():
        
        idx = int(idx)-1
        
        if idx > (len(names_checked)-1) or idx < 0:
            raise IndexError('The entered number is not one of the choices')
        
        for name_checked in names_checked:
            
            if name_checked == names_checked[idx]:
                continue
                
            else:
                matches_final[name_checked]['Maps_to'] = names_checked[idx]
                matches_final[names_checked[idx]]['Mapped_by'].add(name_checked)
                
                for name_to_ignore in names_checked:
                    if name_to_ignore != names_checked[idx] and name_to_ignore != name_checked:
                        matches_final[name_checked]['Ignores'].add(name_to_ignore)
        
    elif len(idx) == 0:
        
        # If the names were just two and they do not refer to the same player, an ignore
        # relationship is set between the two so they will not be analized in the name-to-name
        # section
        if len(names_checked) == 2:
            matches_final[names_checked[0]]['Ignores'].add(names_checked[1])
            matches_final[names_checked[1]]['Ignores'].add(names_checked[0])
        continue
    
    else:
        raise ValueError('The entered value is invalid')
        
    # -------------------- NAME-TO-NAME MATCH SECTION --------------------
    # For names that still have unresolved matches, check them
            
    for el in matches[name]:
        
        # Skip the matched name if it has already a relationship with the key name ('name' variable)
        if el[0] in matches_final[name]['Mapped_by'] or el[0] == matches_final[name]['Maps_to']\
            or el[0] in matches_final[name]['Ignores']:
                continue
        
        # Asks if the two names matches
        check = input(f'Is {el[0]} a good match for {name} ([y]/n)? ' )
        
        # If so, it asks to choos which of the two should be considered the proper one and update
        # the data accordingly
        if (len(check) == 0) or (check == 'y'):
            check = input(f'-> {el[0]} or {name} should be the proper name (1/2)? ' )
            
            if check == '1':
                matches_final[name]['Maps_to'] = el[0]
                matches_final[el[0]]['Mapped_by'].add(name)
                
            elif check == '2':
                matches_final[el[0]]['Maps_to'] = name
                matches_final[name]['Mapped_by'].add(el[0])
                
            else:
                raise ValueError(f'{check} is an invalid answer')
                
        # If they do not match an ignore relationship is set between the two
        elif check == 'n':
            matches_final[name]['Ignores'].add(el[0])
            matches_final[el[0]]['Ignores'].add(name)
        
        else:
            raise ValueError(f'{check} is an invalid answer')
# Out:
# Do the following names all refer to the same player?
#  1. Adrian
#  2. Adrian Mariappa
#  3. Adrian San Miguel del Castillo
#  4. Adrian Bernabe
#  5. Adrian Blake
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Dan Agyei
#  2. Daniel Agyei
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Dele Alli
#  2. Bamidele Alli
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Harry Arter
#  2. Harry Tyrer
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Charlie Austin
#  2. Charlie Patino
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Antonio Barragan
#  2. Antonio Barreca
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Asmir Begovic
#  2. Asmir BegoviA
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Hector Bellerin
#  2. Hector BellerAn
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Fabio Borini
#  2. Fabio
#  3. Fabio Carvalho
#  4. Fabio Silva
#  5. Fabio Vieira
#  6. Fabio Freitas Gouveia Carvalho
#  7. Fabio Pereira da Silva
#  8. Fabio Ferreira Vieira
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Jonathan Calleri
#  2. Jonathan Walters
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Joel Castro Pereira
#  2. Joel Dinis Castro Pereira
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Santi Cazorla
#  2. Santiago Cazorla
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Calum Chambers
#  2. Luke Chambers
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Ben Chilwell
#  2. Benjamin Chilwell
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Lee Chung-yong
#  2. Chung-yong Lee
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Diego Costa
#  2. Diego Da Silva Costa
#  3. Xande Nascimento da Costa Silva
#  4. Xande Silva
#  5. Alexandre Nascimento Costa Silva
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Philippe Coutinho
#  2. Philippe Coutinho Correia
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Danny Drinkwater
#  2. Daniel Drinkwater
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Ovie Ejaria
#  2. Oviemuno Ejaria
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Ahmed Elmohamady
#  2. Ahmed El Mohamady
# If so, enter the number of the proper name, otherwise enter nothing: 2
#
# Do the following names all refer to the same player?
#  1. Mohamed Elneny
#  2. Mohamed Naser El Sayed Elneny
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Bernardo Espinosa
#  2. Bernardo
#  3. Bernardo Espinosa Zuniga
#  4. Bernardo Silva
#  5. Bernardo Mota Veiga de Carvalho e Silva
#  6. Bernardo Fernandes da Silva Junior
#  7. Bernardo Fernandes Da Silva Junior
#  8. Bernardo Veiga de Carvalho e Silva
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Fabio
#  2. Fabio Borini
#  3. Fabio Carvalho
#  4. Fabio Silva
#  5. Fabio Vieira
#  6. Fabio Freitas Gouveia Carvalho
#  7. Fabio Pereira da Silva
#  8. Fabio Ferreira Vieira
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Cesc Fabregas
#  2. Cesc FA bregas
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Edimilson Fernandes
#  2. Gedson Fernandes
#  3. Gedson Carvalho Fernandes
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Fernandinho
#  2. Fernando
#  3. Fernando Llorente
#  4. Fernando Marcal
#  5. Fernando Luiz Rosa
#  6. Fernando Francisco Reges
#  7. Fernando MarASSal
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Fernando
#  2. Fernando Llorente
#  3. Fernando Marcal
#  4. Fernando Luiz Rosa
#  5. Fernando Francisco Reges
#  6. Fernando MarASSal
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Roberto Firmino
#  2. Roberto
#  3. Roberto Pereyra
#  4. Roberto Jimenez Gago
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Michael Folivi
#  2. Michael Olise
#  3. Michael Olakigbe
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Zeki Fryers
#  2. Ezekiel Fryers
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Idrissa Gana Gueye
#  2. Idrissa Gueye
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Aleix Garcia
#  2. Aleix Garcia Serrano
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. David de Gea
#  2. David De Gea
#  3. David De Gea Quintana
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Angel Gomes
#  2. Andre Gomes
#  3. Andre Filipe Tavares Gomes
#  4. Andre Tavares Gomes
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Heurelho Gomes
#  2. Heurelho da Silva Gomes
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Brad Guzan
#  2. Bradley Guzan
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Josh Harrop
#  2. Joshua Harrop
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Jordan Henderson
#  2. Dean Henderson
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Abel Hernandez
#  2. Pablo Hernandez
#  3. Onel Hernandez
#  4. Pablo Hernandez DomAnguez
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Son Heung-min
#  2. Heung-Min Son
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Pierre Hojbjerg
#  2. Pierre-Emile Hojbjerg
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Didier Ibrahim Ndong
#  2. Didier Ndong
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Matty James
#  2. Matthew James
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Gabriel Jesus
#  2. Gabriel Fernando de Jesus
#  3. Fernando
#  4. Fernando Llorente
#  5. Fernando Marcal
#  6. Fernando Luiz Rosa
#  7. Fernando Francisco Reges
#  8. Fernando MarASSal
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Glen Johnson
#  2. Ben Johnson
#  3. Brennan Johnson
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Kenedy
#  2. Robert Kenedy Nunes do Nascimento
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Bojan Krkic
#  2. Bojan Krkic Perez
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Lucas Leiva
#  2. Leiva Lucas
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Fernando Llorente
#  2. Fernando
#  3. Fernando Marcal
#  4. Fernando Luiz Rosa
#  5. Fernando Francisco Reges
#  6. Fernando MarASSal
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. David Luiz
#  2. David Luiz Moreira Marinho
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Javier Manquillo
#  2. Javier Manquillo Gaitan
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Adrian Mariappa
#  2. Adrian
#  3. Adrian San Miguel del Castillo
#  4. Adrian Bernabe
#  5. Adrian Blake
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Emiliano Martinez
#  2. Damian Emiliano Martinez
#  3. Emiliano MartAnez
#  4. Lisandro Martinez
#  5. Emiliano MartAnez Romero
#  6. Lisandro MartAnez
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Bruno Martins Indi
#  2. Bruno
#  3. Bruno Ecuele Manga
#  4. Bruno Fernandes
#  5. Bruno Jordao
#  6. Bruno Miguel Borges Fernandes
#  7. Bruno Borges Fernandes
#  8. Bruno Andre Cavaco Jordao
#  9. Bruno Andre Cavaco JordAPSo
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Brandon Mason
#  2. Brandon Austin
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. James McArthur
#  2. James McCarthy
#  3. Alex McCarthy
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Oliver McBurnie
#  2. Oliver Burke
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. James McCarthy
#  2. James McArthur
#  3. Alex McCarthy
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Memphis
#  2. Memphis Depay
# If so, enter the number of the proper name, otherwise enter nothing: 2
#
# Do the following names all refer to the same player?
#  1. James Morrison
#  2. James Morris
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Georges-Kevin N'Koudou
#  2. Georges-Kevin Nkoudou
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Havard Nordtveit
#  2. HAY=vard Nordtveit
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Emilio Nsue
#  2. Emilio Nsue Lopez
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Allan Nyom
#  2. Allan
#  3. Allan-Romeo Nyom
#  4. Allan Saint-Maximin
#  5. Allan Tchaptchet
#  6. Allan McGregor
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Pedro Obiang
#  2. Pedro
#  3. Joao Pedro
#  4. Pedro Neto
#  5. Pedro Porro
#  6. Neto
#  7. Pedro Lomba Neto
#  8. Norberto Murara Neto
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Josh Onomah
#  2. Joshua Onomah
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Oscar
#  2. Oscar dos Santos Emboaba Junior
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Bryan Oviedo
#  2. Bryan
#  3. Joe Bryan
#  4. Kean Bryan
#  5. Bryan Mbeumo
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Mesut Ozil
#  2. Mesut Azil
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Pedro
#  2. Pedro Obiang
#  3. Joao Pedro
#  4. Pedro Neto
#  5. Pedro Porro
#  6. Neto
#  7. Pedro Lomba Neto
#  8. Norberto Murara Neto
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Roberto Pereyra
#  2. Roberto
#  3. Roberto Firmino
#  4. Roberto Jimenez Gago
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Lucas Perez
#  2. Lucas Perri
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Sebastian Prodl
#  2. Sebastian PrAPdl
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Aaron Ramsey
#  2. Aaron Ramsdale
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Jay Rodriguez
#  2. James Rodriguez
#  3. Pedro Rodriguez Ledesma
#  4. Bruno GuimarAPSes Rodriguez Moura
#  5. James RodrAguez
#  6. Pedro
#  7. Pedro RodrAguez Ledesma
#  8. Bruno
#  9. Pedro Obiang
#  10. Joao Pedro
#  11. Pedro Neto
#  12. Pedro Porro
#  13. Bruno Martins Indi
#  14. Bruno Ecuele Manga
#  15. Bruno Fernandes
#  16. Bruno Jordao
#  17. Neto
#  18. Pedro Lomba Neto
#  19. Bruno Miguel Borges Fernandes
#  20. Bruno Borges Fernandes
#  21. Bruno Andre Cavaco Jordao
#  22. Norberto Murara Neto
#  23. Bruno Andre Cavaco JordAPSo
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Oriol Romeu
#  2. Oriol Romeu Vidal
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Josh Sims
#  2. Joshua Sims
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Brad Smith
#  2. Bradley Smith
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Cedric Soares
#  2. Cedric Alves Soares
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. John Stones
#  2. Sam Johnstone
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Isaac Success
#  2. Isaac Success Ajayi
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Ki Sung-yueng
#  2. Sung-yueng Ki
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Neil Taylor
#  2. Joel Taylor
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Yaya Toure
#  2. Gnegneri Yaya Toure
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Adama Traore
#  2. Adama Traore Diarra
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Kyle Walker
#  2. Kyle Walker-Peters
# If so, enter the number of the proper name, otherwise enter nothing:
# Do the following names all refer to the same player?
#  1. Jonathan Walters
#  2. Jonathan Calleri
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Willian
#  2. Willian Jose
#  3. Willian Borges Da Silva
#  4. Willian Jose Da Silva
#  5. Willian Borges da Silva
#  6. Joe Williams
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Harry Winks
#  2. Harry Lewis
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Matt Worthington
#  2. Matthew Worthington
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Muhamed Besic
#  2. Muhamed BeaiA
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Gaetan Bong
#  2. GaA<<tan Bong
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Bruno
#  2. Bruno Martins Indi
#  3. Bruno Ecuele Manga
#  4. Bruno Fernandes
#  5. Bruno Jordao
#  6. Bruno Miguel Borges Fernandes
#  7. Bruno Borges Fernandes
#  8. Bruno Andre Cavaco Jordao
#  9. Bruno Andre Cavaco JordAPSo
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Oliver Burke
#  2. Oliver McBurnie
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Danilo
#  2. Danilo Luiz da Silva
#  3. Danilo dos Santos de Oliveira
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Aleksandar Dragovic
#  2. Aleksandar Mitrovic
#  3. Aleksandar MitroviA
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Ederson
#  2. Ederson Santana de Moraes
#  3. Emerson
#  4. Emerson Hyndman
#  5. Emerson Palmieri
#  6. Emerson Palmieri dos Santos
#  7. Emerson Aparecido Leite de Souza Junior
#  8. Emerson Leite de Souza Junior
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Tom Edwards
#  2. Thomas Edwards
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Rob Elliot
#  2. Robert Elliot
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Paulo Gazzaniga
#  2. Paulo Gazzaniga Farias
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Joe Gomez
#  2. Joseph Gomez
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Pascal Gross
#  2. Pascal GroA
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Ahmed Hegazi
#  2. Ahmed El-Sayed Hegazi
#  3. Ahmed El-Sayed Hegazy
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Javier Hernandez
#  2. Javier Hernandez Balcazar
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Emerson Hyndman
#  2. Emerson
#  3. Emerson Palmieri
#  4. Emerson Palmieri dos Santos
#  5. Emerson Aparecido Leite de Souza Junior
#  6. Emerson Leite de Souza Junior
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Jose Izquierdo
#  2. Jose Heriberto Izquierdo Mena
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Jese
#  2. Jese RodrAguez Ruiz
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Mathias Jorgensen
#  2. Mathias Jensen
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Victor Lindelof
#  2. Victor LindelAPf
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Jonas Lossl
#  2. Jonas LAPssl
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Chris Lowe
#  2. Chris LAPwe
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Alex McCarthy
#  2. James McCarthy
#  3. James McArthur
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Aleksandar Mitrovic
#  2. Aleksandar MitroviA
#  3. Aleksandar Dragovic
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Lucas Moura
#  2. Lucas Rodrigues Moura da Silva
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Charly Musonda Jr.
#  2. Charly Musonda
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Eddie Nketiah
#  2. Edward Nketiah
# If so, enter the number of the proper name, otherwise enter nothing: 1
#
# Do the following names all refer to the same player?
#  1. Emerson Palmieri
#  2. Emerson
#  3. Emerson Palmieri dos Santos
#  4. Emerson Hyndman
#  5. Emerson Aparecido Leite de Souza Junior
#  6. Emerson Leite de Souza Junior
# If so, enter the number of the proper name, otherwise enter nothing:
#
# Do the following names all refer to the same player?
#  1. Davy Propper
#  2. Davy PrAPpper
