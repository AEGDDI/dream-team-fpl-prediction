# %%
import pandas as pd

# Load the players_agg.xlsx file
players_agg_path = r'C:\Users\aldi\Documents\GitHub\dream-team-fpl-prediction\data\players_agg.xlsx'
#players_agg_path = r'C:\Users\ALESSANDRO\Documents\GitHub\dream-team-fpl-prediction\data\players_agg.xlsx'
players_agg_df = pd.read_excel(players_agg_path)

# Load the fpl_data.csv file
fpl_data_path = r'C:\Users\aldi\Documents\GitHub\dream-team-fpl-prediction\data\fpl_data.xlsx'
#fpl_data_path = r'C:\Users\ALESSANDRO\Documents\GitHub\dream-team-fpl-prediction\data\fpl_data.csv'
fpl_data_df = pd.read_excel(fpl_data_path)

# Perform an outer join on 'Player' and 'Season' variables
merged_df = pd.merge(players_agg_df, fpl_data_df, on=['Player', 'Season'], how='outer')

# Filter the merged DataFrame for season 2016-2017 onwards and total_points greater than 0
matched_obs = merged_df[(merged_df['Season'] >= '2016-2017') & (merged_df['total_points'] > 0)]

# Display the first few rows of the filtered DataFrame
matched_obs.head()
# Out:
#          Season               Player Nation Pos          Squad   Age    Born  \
# 7470  2016-2017  Patrick van Aanholt    NED  DF     Sunderland  25.0  1990.0
# 7471  2016-2017         Charlie Adam    SCO  MF     Stoke City  30.0  1985.0
# 7472  2016-2017        Albert Adomah    GHA  MF  Middlesbrough  28.0  1987.0
# 7474  2016-2017      Ibrahim Afellay    NED  MF     Stoke City  30.0  1986.0
# 7475  2016-2017          Benik Afobe    COD  FW    Bournemouth  23.0  1993.0
#
#         MP  Starts     Min  ...  goals_conceded  goals_scored  ict_index  \
# 7470  32.0    28.0  2498.0  ...            53.0           5.0      153.5
# 7471  24.0    17.0  1517.0  ...            23.0           1.0      106.7
# 7472   2.0     1.0   122.0  ...             2.0           0.0        6.0
# 7474  12.0     3.0   384.0  ...             5.0           0.0       14.8
# 7475  31.0    14.0  1461.0  ...            24.0           6.0      130.8
#
#       influence  minutes  red_cards  selected_by_percent  threat  \
# 7470      616.0   2498.0        0.0                  3.6   383.0
# 7471      263.4   1491.0        0.0                  0.3   328.0
# 7472        8.4    122.0        0.0                  0.0    33.0
# 7474       32.0    384.0        0.0                  0.0    63.0
# 7475      350.0   1458.0        0.0                  1.2   639.0
#
#       total_points  yellow_cards
# 7470          98.0           3.0
# 7471          59.0           7.0
# 7472           3.0           0.0
# 7474          15.0           0.0
# 7475          88.0           1.0
#
# [5 rows x 52 columns]

# %%
# Count observations with 'total_points' greater than 0
count_total_points = len(matched_obs)

# Filter the merged DataFrame for season 2016-2017 onwards and total_points equal NaN
unmatched_obs = merged_df[(merged_df['Season'] >= '2016-2017') & (merged_df['total_points'].isna())]
# Count observations with NaN 'total_points'
count_nan_total_points = len(unmatched_obs[unmatched_obs['total_points'].isna()])

print("Number of observations with 'total_points' > 0:", count_total_points)
print("Number of observations with NaN 'total_points':", count_nan_total_points)
# Out:
# Number of observations with 'total_points' > 0: 3667
# Number of observations with NaN 'total_points': 936

# %%
unmatched_obs.head(50)
# Out:
#          Season                   Player Nation Pos            Squad   Age  \
# 7473  2016-2017                   Adrián    ESP  GK         West Ham  29.0
# 7477  2016-2017                Dan Agyei    ENG  FW          Burnley  19.0
# 7484  2016-2017                Dele Alli    ENG  MF        Tottenham  20.0
# 7495  2016-2017         Marko Arnautović    AUT  MF       Stoke City  27.0
# 7515  2016-2017            Asmir Begović    BIH  GK          Chelsea  29.0
# 7522  2016-2017  Jóhann Berg Guðmundsson    ISL  MF          Burnley  25.0
# 7550  2016-2017           Étienne Capoue    FRA  MF          Watford  28.0
# 7555  2016-2017      Joel Castro Pereira    POR  GK   Manchester Utd  20.0
# 7558  2016-2017            Santi Cazorla    ESP  MF          Arsenal  31.0
# 7559  2016-2017                Petr Čech    CZE  GK          Arsenal  34.0
# 7563  2016-2017             Ben Chilwell    ENG  DF   Leicester City  19.0
# 7564  2016-2017           Lee Chung-yong    KOR  MF   Crystal Palace  28.0
# 7571  2016-2017           Séamus Coleman    IRL  DF          Everton  27.0
# 7577  2016-2017              Diego Costa    ESP  FW          Chelsea  27.0
# 7607  2016-2017         Danny Drinkwater    ENG  MF   Leicester City  26.0
# 7609  2016-2017              Ovie Ejaria    ENG  FW        Liverpool  18.0
# 7615  2016-2017        Bernardo Espinosa    COL  DF    Middlesbrough  27.0
# 7617  2016-2017         Łukasz Fabiański    POL  GK     Swansea City  31.0
# 7618  2016-2017                    Fábio    BRA  DF    Middlesbrough  26.0
# 7626  2016-2017              Fernandinho    BRA  MF  Manchester City  31.0
# 7627  2016-2017                 Fernando    BRA  MF  Manchester City  29.0
# 7636  2016-2017               José Fonte    POR  DF         West Ham  32.0
# 7644  2016-2017              Zeki Fryers    ENG  DF   Crystal Palace  23.0
# 7650  2016-2017       Idrissa Gana Gueye    SEN  MF          Everton  26.0
# 7651  2016-2017             Aleix García    ESP  MF  Manchester City  19.0
# 7671  2016-2017             Marko Grujić    SRB  MF        Liverpool  20.0
# 7672  2016-2017         Adlène Guedioura    ALG  MF    Middlesbrough  30.0
# 7673  2016-2017           İlkay Gündoğan    GER  MF  Manchester City  25.0
# 7674  2016-2017               Brad Guzan    USA  GK    Middlesbrough  31.0
# 7675  2016-2017              Josh Harrop    ENG  FW   Manchester Utd  20.0
# 7685  2016-2017            Son Heung-min    KOR  MF        Tottenham  24.0
# 7693  2016-2017          Pierre Højbjerg    DEN  MF      Southampton  20.0
# 7695  2016-2017     Didier Ibrahim Ndong    GAB  MF       Sunderland  22.0
# 7696  2016-2017       Zlatan Ibrahimović    SWE  FW   Manchester Utd  34.0
# 7700  2016-2017       Branislav Ivanović    SRB  DF          Chelsea  32.0
# 7703  2016-2017          Eldin Jakupović    SUI  GK        Hull City  31.0
# 7704  2016-2017              Matty James    ENG  MF   Leicester City  25.0
# 7710  2016-2017            Gabriel Jesus    BRA  FW  Manchester City  19.0
# 7717  2016-2017            Younès Kaboul    FRA  DF       Sunderland  30.0
# 7725  2016-2017                   Kenedy    BRA  FW          Chelsea  20.0
# 7726  2016-2017                   Kenedy    BRA  MF          Chelsea  20.0
# 7741  2016-2017              Bojan Krkić    ESP  MF       Stoke City  25.0
# 7744  2016-2017              Érik Lamela    ARG  MF        Tottenham  24.0
# 7746  2016-2017              Seb Larsson    SWE  MF       Sunderland  31.0
# 7749  2016-2017              Lucas Leiva    BRA  MF        Liverpool  29.0
# 7766  2016-2017               David Luiz    BRA  DF          Chelsea  29.0
# 7777  2016-2017           Lazar Marković    SRB  MF        Hull City  22.0
# 7782  2016-2017        Emiliano Martínez    ARG  GK          Arsenal  23.0
# 7788  2016-2017            Nemanja Matić    SRB  MF          Chelsea  27.0
# 7789  2016-2017               Joël Matip    CMR  DF        Liverpool  24.0
#
#         Born    MP  Starts     Min  ...  goals_conceded  goals_scored  \
# 7473  1987.0  16.0    16.0  1440.0  ...             NaN           NaN
# 7477  1997.0   3.0     0.0    25.0  ...             NaN           NaN
# 7484  1996.0  37.0    35.0  3034.0  ...             NaN           NaN
# 7495  1989.0  32.0    32.0  2714.0  ...             NaN           NaN
# 7515  1987.0   2.0     2.0   180.0  ...             NaN           NaN
# 7522  1990.0  20.0    10.0   998.0  ...             NaN           NaN
# 7550  1988.0  37.0    37.0  3203.0  ...             NaN           NaN
# 7555  1996.0   1.0     1.0    90.0  ...             NaN           NaN
# 7558  1984.0   8.0     7.0   618.0  ...             NaN           NaN
# 7559  1982.0  35.0    35.0  3097.0  ...             NaN           NaN
# 7563  1996.0  12.0     7.0   699.0  ...             NaN           NaN
# 7564  1988.0  15.0     4.0   471.0  ...             NaN           NaN
# 7571  1988.0  26.0    26.0  2316.0  ...             NaN           NaN
# 7577  1988.0  35.0    35.0  3082.0  ...             NaN           NaN
# 7607  1990.0  29.0    27.0  2466.0  ...             NaN           NaN
# 7609  1997.0   2.0     0.0     8.0  ...             NaN           NaN
# 7615  1989.0  11.0    10.0   975.0  ...             NaN           NaN
# 7617  1985.0  37.0    37.0  3330.0  ...             NaN           NaN
# 7618  1990.0  24.0    21.0  1847.0  ...             NaN           NaN
# 7626  1985.0  32.0    31.0  2756.0  ...             NaN           NaN
# 7627  1987.0  15.0     5.0   568.0  ...             NaN           NaN
# 7636  1983.0  33.0    33.0  2934.0  ...             NaN           NaN
# 7644  1992.0   8.0     0.0   188.0  ...             NaN           NaN
# 7650  1989.0  33.0    32.0  2681.0  ...             NaN           NaN
# 7651  1997.0   4.0     1.0    77.0  ...             NaN           NaN
# 7671  1996.0   5.0     0.0    43.0  ...             NaN           NaN
# 7672  1985.0  17.0     9.0   861.0  ...             NaN           NaN
# 7673  1990.0  10.0     9.0   704.0  ...             NaN           NaN
# 7674  1984.0  10.0    10.0   900.0  ...             NaN           NaN
# 7675  1995.0   1.0     1.0    90.0  ...             NaN           NaN
# 7685  1992.0  34.0    23.0  2062.0  ...             NaN           NaN
# 7693  1995.0  22.0    14.0  1301.0  ...             NaN           NaN
# 7695  1994.0  31.0    27.0  2520.0  ...             NaN           NaN
# 7696  1981.0  28.0    27.0  2438.0  ...             NaN           NaN
# 7700  1984.0  13.0     6.0   589.0  ...             NaN           NaN
# 7703  1984.0  22.0    22.0  1980.0  ...             NaN           NaN
# 7704  1991.0   1.0     0.0     1.0  ...             NaN           NaN
# 7710  1997.0  10.0     8.0   650.0  ...             NaN           NaN
# 7717  1986.0  23.0    23.0  1910.0  ...             NaN           NaN
# 7725  1996.0   2.0     1.0    90.0  ...             NaN           NaN
# 7726  1996.0   2.0     1.0    90.0  ...             NaN           NaN
# 7741  1990.0   9.0     5.0   475.0  ...             NaN           NaN
# 7744  1992.0   9.0     6.0   594.0  ...             NaN           NaN
# 7746  1985.0  21.0    17.0  1469.0  ...             NaN           NaN
# 7749  1987.0  24.0    12.0  1112.0  ...             NaN           NaN
# 7766  1987.0  33.0    33.0  2954.0  ...             NaN           NaN
# 7777  1994.0  12.0    12.0  1005.0  ...             NaN           NaN
# 7782  1992.0   2.0     2.0   180.0  ...             NaN           NaN
# 7788  1988.0  35.0    30.0  2694.0  ...             NaN           NaN
# 7789  1991.0  29.0    27.0  2457.0  ...             NaN           NaN
#
#       ict_index  influence  minutes  red_cards  selected_by_percent  threat  \
# 7473        NaN        NaN      NaN        NaN                  NaN     NaN
# 7477        NaN        NaN      NaN        NaN                  NaN     NaN
# 7484        NaN        NaN      NaN        NaN                  NaN     NaN
# 7495        NaN        NaN      NaN        NaN                  NaN     NaN
# 7515        NaN        NaN      NaN        NaN                  NaN     NaN
# 7522        NaN        NaN      NaN        NaN                  NaN     NaN
# 7550        NaN        NaN      NaN        NaN                  NaN     NaN
# 7555        NaN        NaN      NaN        NaN                  NaN     NaN
# 7558        NaN        NaN      NaN        NaN                  NaN     NaN
# 7559        NaN        NaN      NaN        NaN                  NaN     NaN
# 7563        NaN        NaN      NaN        NaN                  NaN     NaN
# 7564        NaN        NaN      NaN        NaN                  NaN     NaN
# 7571        NaN        NaN      NaN        NaN                  NaN     NaN
# 7577        NaN        NaN      NaN        NaN                  NaN     NaN
# 7607        NaN        NaN      NaN        NaN                  NaN     NaN
# 7609        NaN        NaN      NaN        NaN                  NaN     NaN
# 7615        NaN        NaN      NaN        NaN                  NaN     NaN
# 7617        NaN        NaN      NaN        NaN                  NaN     NaN
# 7618        NaN        NaN      NaN        NaN                  NaN     NaN
# 7626        NaN        NaN      NaN        NaN                  NaN     NaN
# 7627        NaN        NaN      NaN        NaN                  NaN     NaN
# 7636        NaN        NaN      NaN        NaN                  NaN     NaN
# 7644        NaN        NaN      NaN        NaN                  NaN     NaN
# 7650        NaN        NaN      NaN        NaN                  NaN     NaN
# 7651        NaN        NaN      NaN        NaN                  NaN     NaN
# 7671        NaN        NaN      NaN        NaN                  NaN     NaN
# 7672        NaN        NaN      NaN        NaN                  NaN     NaN
# 7673        NaN        NaN      NaN        NaN                  NaN     NaN
# 7674        NaN        NaN      NaN        NaN                  NaN     NaN
# 7675        NaN        NaN      NaN        NaN                  NaN     NaN
# 7685        NaN        NaN      NaN        NaN                  NaN     NaN
# 7693        NaN        NaN      NaN        NaN                  NaN     NaN
# 7695        NaN        NaN      NaN        NaN                  NaN     NaN
# 7696        NaN        NaN      NaN        NaN                  NaN     NaN
# 7700        NaN        NaN      NaN        NaN                  NaN     NaN
# 7703        NaN        NaN      NaN        NaN                  NaN     NaN
# 7704        NaN        NaN      NaN        NaN                  NaN     NaN
# 7710        NaN        NaN      NaN        NaN                  NaN     NaN
# 7717        NaN        NaN      NaN        NaN                  NaN     NaN
# 7725        NaN        NaN      NaN        NaN                  NaN     NaN
# 7726        NaN        NaN      NaN        NaN                  NaN     NaN
# 7741        NaN        NaN      NaN        NaN                  NaN     NaN
# 7744        NaN        NaN      NaN        NaN                  NaN     NaN
# 7746        NaN        NaN      NaN        NaN                  NaN     NaN
# 7749        NaN        NaN      NaN        NaN                  NaN     NaN
# 7766        NaN        NaN      NaN        NaN                  NaN     NaN
# 7777        NaN        NaN      NaN        NaN                  NaN     NaN
# 7782        NaN        NaN      NaN        NaN                  NaN     NaN
# 7788        NaN        NaN      NaN        NaN                  NaN     NaN
# 7789        NaN        NaN      NaN        NaN                  NaN     NaN
#
#       total_points  yellow_cards
# 7473           NaN           NaN
# 7477           NaN           NaN
# 7484           NaN           NaN
# 7495           NaN           NaN
# 7515           NaN           NaN
# 7522           NaN           NaN
# 7550           NaN           NaN
# 7555           NaN           NaN
# 7558           NaN           NaN
# 7559           NaN           NaN
# 7563           NaN           NaN
# 7564           NaN           NaN
# 7571           NaN           NaN
# 7577           NaN           NaN
# 7607           NaN           NaN
# 7609           NaN           NaN
# 7615           NaN           NaN
# 7617           NaN           NaN
# 7618           NaN           NaN
# 7626           NaN           NaN
# 7627           NaN           NaN
# 7636           NaN           NaN
# 7644           NaN           NaN
# 7650           NaN           NaN
# 7651           NaN           NaN
# 7671           NaN           NaN
# 7672           NaN           NaN
# 7673           NaN           NaN
# 7674           NaN           NaN
# 7675           NaN           NaN
# 7685           NaN           NaN
# 7693           NaN           NaN
# 7695           NaN           NaN
# 7696           NaN           NaN
# 7700           NaN           NaN
# 7703           NaN           NaN
# 7704           NaN           NaN
# 7710           NaN           NaN
# 7717           NaN           NaN
# 7725           NaN           NaN
# 7726           NaN           NaN
# 7741           NaN           NaN
# 7744           NaN           NaN
# 7746           NaN           NaN
# 7749           NaN           NaN
# 7766           NaN           NaN
# 7777           NaN           NaN
# 7782           NaN           NaN
# 7788           NaN           NaN
# 7789           NaN           NaN
#
# [50 rows x 52 columns]

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Filter the merged_df for the season 2016-2017
filtered_df = merged_df[merged_df['Season'] >= '2016-2017']

# Set a threshold for matching similarity
threshold = 90

# Create a dictionary to store the matched names
matched_names = {}

# Iterate over each unique name in the filtered DataFrame
for name in filtered_df['Player'].unique():
    # Check if the name has already been matched and is not empty
    if name not in matched_names and name != '':
        # Split the name into first name and surname
        name_parts = name.split(' ')
        first_name = name_parts[0] if len(name_parts) > 0 else ''
        surname = ' '.join(name_parts[1:]) if len(name_parts) > 1 else ''

        # Find potential matches for the first name
        potential_matches_first = process.extractBests(first_name, filtered_df['Player'].unique(), scorer=fuzz.token_set_ratio, score_cutoff=threshold)

        # Find potential matches for the surname
        potential_matches_surname = process.extractBests(surname, filtered_df['Player'].unique(), scorer=fuzz.token_set_ratio, score_cutoff=threshold)

        # Check if there are any potential matches for both first name and surname
        if len(potential_matches_first) > 1 and len(potential_matches_surname) > 1:
            # Iterate over potential matches and merge the data
            for match_first in potential_matches_first:
                for match_surname in potential_matches_surname:
                    if match_first[0] != name and match_surname[0] != name and match_first[0] == match_surname[0]:
                        matched_names[match_first[0]] = name

        # Check for substring matches
        potential_matches_substring = process.extractBests(name, filtered_df['Player'].unique(), scorer=fuzz.token_set_ratio, score_cutoff=threshold)
        for match_substring in potential_matches_substring:
            if match_substring[0] != name and name in match_substring[0]:
                matched_names[match_substring[0]] = name

# Update the 'Player' column with the merged names
filtered_df.loc[:, 'Player'] = filtered_df['Player'].replace(matched_names)

# Print the updated DataFrame
filtered_df.head()

# %%
matched_names
# Out:
# {'Adrian Mariappa': 'Adrian',
#  'Adrian Blake': 'Adrian',
#  'Chung-yong Lee': 'Lee Chung-yong',
#  'Diego Da Silva Costa': 'Diego Costa',
#  'Philippe Coutinho Correia': 'Philippe Coutinho',
#  'Bernardo Espinosa Zúñiga': 'Bernardo Espinosa',
#  'Fabio Borini': 'Fabio',
#  'Fabio Carvalho': 'Fabio',
#  'Fabio Vieira': 'Fabio',
#  'Fabio Pereira da Silva': 'Fabio',
#  'Fabio Henrique Tavares': 'Fabio',
#  'Fernando Llorente': 'Fernando',
#  'Fernando Marçal': 'Fernando',
#  'Fernando Luiz Rosa': 'Fernando',
#  'Fernando Francisco Reges': 'Fernando',
#  'Heung-Min Son': 'Son Heung-min',
#  'Gabriel Fernando de Jesus': 'Gabriel Jesus',
#  'Robert Kenedy Nunes do Nascimento': 'Kenedy',
#  'Bojan Krkic Perez': 'Bojan Krkic',
#  'David Luiz Moreira Marinho': 'David Luiz',
#  'Javier Manquillo GaitÃ¡n': 'Javier Manquillo',
#  'Damian Emiliano Martinez': 'Emiliano Martinez',
#  'Memphis Depay': 'Memphis',
#  'Emilio Nsue Lopez': 'Emilio Nsue',
#  'Oscar dos Santos Emboaba Junior': 'Oscar',
#  'Pedro Obiang': 'Pedro',
#  'João Pedro': 'Pedro',
#  'Pedro Neto': 'Neto',
#  'Pedro Porro': 'Pedro',
#  'Oriol Romeu Vidal': 'Oriol Romeu',
#  'Isaac Success Ajayi': 'Isaac Success',
#  'Sung-yueng Ki': 'Ki Sung-yueng',
#  'Kyle Walker-Peters': 'Kyle Walker',
#  'Willian José': 'Willian',
#  'Willian Borges Da Silva': 'Willian',
#  'Willian JosÃ© Da Silva': 'Willian',
#  'Willian Borges da Silva': 'Willian',
#  'Bruno Martins Indi': 'Bruno',
#  'Bruno Ecuele Manga': 'Bruno',
#  'Bruno Fernandes': 'Bruno',
#  'Bruno Jordão': 'Bruno',
#  'Danilo Luiz da Silva': 'Danilo',
#  'Danilo dos Santos de Oliveira': 'Danilo',
#  'Ederson Santana de Moraes': 'Ederson',
#  'Paulo Gazzaniga Farias': 'Paulo Gazzaniga',
#  'Ahmed El-Sayed Hegazi': 'Ahmed Hegazi',
#  'Emerson Palmieri dos Santos': 'Emerson',
#  'Richarlison de Andrade': 'Richarlison',
#  'Alisson Ramses Becker': 'Alisson',
#  'Felipe Anderson Pereira Gomes': 'Felipe',
#  'Bernard AnÃ\xadcio Caldeira Duarte': 'Bernard',
#  'Bernard Ashley-Seal': 'Bernard',
#  'Bernardo': 'Bernard',
#  'Ivan Ricardo Neves Abreu Cavaleiro': 'Ivan Cavaleiro',
#  'Ivan Neves Abreu Cavaleiro': 'Ivan Cavaleiro',
#  'Greg Cunninghamm': 'Greg Cunningham',
#  'JosÃ© Diogo Dalot Teixeira': 'Diogo Dalot',
#  'Diogo Dalot Teixeira': 'Diogo Dalot',
#  'Fabricio Agosto RamÃ\xadrez': 'Fabricio',
#  'David Junior Hoilett': 'Junior Hoilett',
#  'Jefferson Lerma SolÃ\xads': 'Jefferson Lerma',
#  'Bobby Decordova-Reid': 'Bobby Reid',
#  'Bobby De Cordova-Reid': 'Bobby Reid',
#  'Ashley Darel Jazz Richards': 'Jazz Richards',
#  'Jean Michael Seri': 'Jean Seri',
#  'Jean MichaÃ«l Seri': 'Jean Seri',
#  'Lucas Torreira di Pascua': 'Lucas Torreira',
#  'Arnaut Danjuma Groeneveld': 'Arnaut Danjuma',
#  'Pablo Fornals Malla': 'Pablo Fornals',
#  'Joelinton CÃ¡ssio ApolinÃ¡rio de Lira': 'Joelinton',
#  'Diogo Jota': 'Jota',
#  'Ezri Konsa Ngoyo': 'Ezri Konsa',
#  'Douglas Luiz Soares de Paulo': 'Douglas Luiz',
#  'Gabriel Teodoro Martinelli Silva': 'Martinelli',
#  'Gabriel Martinelli Silva': 'Martinelli',
#  'Roberto Firmino': 'Roberto',
#  'Roberto Pereyra': 'Roberto',
#  'Roberto Jimenez Gago': 'Roberto',
#  'Mbwana Ally Samatta': 'Mbwana Samatta',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Allan Nyom': 'Allan',
#  'Allan Saint-Maximin': 'Allan',
#  'Allan Tchaptchet': 'Allan',
#  'Allan McGregor': 'Allan',
#  'Ian Carlo Poveda-Ocampo': 'Ian Carlo Poveda',
#  'Jaden Philogene-Bidace': 'Jaden Philogene Bidace',
#  'Rodrigo Bentancur': 'Rodrigo',
#  'Rodrigo Hernandez': 'Rodrigo',
#  'Rodrigo Moreno': 'Rodrigo',
#  'Rodrigo Muniz Carvalho': 'Rodrigo',
#  'Carlos Vinicius Alves Morais': 'Carlos Vinicius',
#  'Bryan Oviedo': 'Bryan',
#  'Joe Bryan': 'Bryan',
#  'Kean Bryan': 'Bryan',
#  'Bryan Mbeumo': 'Bryan',
#  'Kayky da Silva Chagas': 'Kayky Chagas',
#  'Marc Cucurella Saseta': 'Marc Cucurella',
#  'Emerson Hyndman': 'Emerson',
#  'Emerson Palmieri': 'Emerson',
#  'Emerson Aparecido Leite de Souza Junior': 'Emerson Leite de Souza Junior',
#  'Oghenekaro Peter Etebo': 'Oghenekaro Etebo',
#  'HÃ©ctor Junior Firpo Adames': 'Junior Firpo',
#  'Junior Firpo Adames': 'Junior Firpo',
#  'Tariqe Fosu-Henry': 'Tariqe Fosu',
#  'Alejandro Garnacho Ferreyra': 'Alejandro Garnacho',
#  'Hee-Chan Hwang': 'Hwang Hee-chan',
#  'Lyanco Evangelista Silveira Neves Vojnovic': 'Lyanco',
#  'Lyanco Silveira Neves Vojnovic': 'Lyanco',
#  'David Raya Martin': 'David Raya',
#  'Mads Roerslev Rasmussen': 'Mads Roerslev',
#  'Cristiano Ronaldo dos Santos Aveiro': 'Cristiano Ronaldo',
#  'Jeremy Sarmiento Morante': 'Jeremy Sarmiento',
#  'Antony Matheus dos Santos': 'Antony',
#  'Armel Bella-Kotchap': 'Armel Bella Kotchap',
#  'Hugo Bueno LÃ³pez': 'Hugo Bueno',
#  'Diego Carlos Santos Silva': 'Diego Carlos',
#  'Felipe Anderson': 'Felipe',
#  'Felipe Augusto de Almeida Monteiro': 'Felipe',
#  'David Datro Fofana': 'Datro Fofana',
#  'Mateo Joseph FernÃ¡ndez': 'Mateo Joseph',
#  'Juan Larios LÃ³pez': 'Juan Larios',
#  'Renan Augusto Lodi dos Santos': 'Renan Lodi',
#  'Pedro Lomba Neto': 'Neto',
#  'Norberto Murara Neto': 'Neto',
#  'Matheus Luiz Nunes': 'Matheus Nunes',
#  'Stefan Ortega Moreno': 'Stefan Ortega',
#  'Facundo Pellistri Rebollo': 'Facundo Pellistri',
#  'Marc Roca JunquÃ©': 'Marc Roca',
#  'Gustavo Henrique Furtado Scarpa': 'Gustavo Scarpa',
#  'Luis Sinisterra LucumÃ\xad': 'Luis Sinisterra',
#  'Kenny Tete': 'Tete',
#  'Lucas Leiva': 'Leiva Lucas',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Didier Ibrahim Ndong': 'Didier Ndong',
#  'Eduardo dos Reis Carvalho': 'Eduardo Dos Reis Carvalho',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'David de Gea': 'David De Gea',
#  'David De Gea Quintana': 'David De Gea',
#  'Rui Pedro dos Santos PatrÃ\xadcio': 'Rui Pedro dos Santos PatrAcio',
#  'Kaine Kesler Hayden': 'Kaine Hayden',
#  'Thiago Alcántara': 'Thiago Thiago',
#  'Thiago Silva': 'Thiago Thiago',
#  'Thiago AlcÃ¡ntara do Nascimento': 'Thiago Thiago',
#  'Thiago Emiliano da Silva': 'Thiago Thiago',
#  'Luke Mbete-Tabu': 'Luke Mbete',
#  'William Thomas Fish': 'William Fish',
#  'Lewis Richardson': 'Lewis Richards',
#  'James Morrison': 'James Morris',
#  'Julio César Enciso': 'Julio Enciso',
#  'Ricardo Domingos Barbosa Pereira': 'Ricardo Barbosa Pereira',
#  'Victor Bernth Kristiansen': 'Victor Kristiansen',
#  'Bernardo Mota Veiga de Carvalho e Silva': 'Bernardo Veiga de Carvalho e Silva'}

# %%
import os
# Export the merged dataset to an xlsx file
output_folder = r'C:\Users\aldi\Documents\GitHub\dream-team-fpl-prediction\data'
# output_path = os.path.join(output_folder, 'matched_df.xlsx')
# matched_df.to_excel(output_path, index=False)
output_path = os.path.join(output_folder, 'filtered_df.xlsx')
filtered_df.to_excel(output_path, index=False)
