# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from getpass import getuser

# Get the current user's name
user = getuser()

# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\dream-team-fpl-prediction\data\ds_gk.xlsx'

# Read the dataset
fpl_data = pd.read_excel(data_path)

# %%
fpl_data.head()
# Out:
#              player     season  goals_scored  assists  total_points  minutes  \
# 0       Artur Boruc  2016-2017             0        0           120     3150
# 1        Tom Heaton  2016-2017             0        0           149     3150
# 2  Thibaut Courtois  2016-2017             0        0           141     3240
# 3   Wayne Hennessey  2016-2017             0        0            92     2610
# 4       Joel Robles  2016-2017             0        1            89     1737
#
#    goals_conceded  creativity  influence  threat  ...  npxg_team  xag_team  \
# 0              63        10.0      815.4       0  ...        NaN       NaN
# 1              48        30.3     1001.6       0  ...        NaN       NaN
# 2              28         0.0      517.6       0  ...        NaN       NaN
# 3              46        31.1      600.4       0  ...        NaN       NaN
# 4              20        10.0      439.2       0  ...        NaN       NaN
#
#    npxg+xag_team  prgc_team  prgp_team  xg_90minutes_team  xag_90minutes_team  \
# 0            NaN        NaN        NaN                NaN                 NaN
# 1            NaN        NaN        NaN                NaN                 NaN
# 2            NaN        NaN        NaN                NaN                 NaN
# 3            NaN        NaN        NaN                NaN                 NaN
# 4            NaN        NaN        NaN                NaN                 NaN
#
#    xg+xag_team npxg_90minutes_team npxg+xag_90minutes_team
# 0          NaN                 NaN                     NaN
# 1          NaN                 NaN                     NaN
# 2          NaN                 NaN                     NaN
# 3          NaN                 NaN                     NaN
# 4          NaN                 NaN                     NaN
#
# [5 rows x 54 columns]
